# %% [markdown]
# ### Environment check

# %%
import sys
import os
from platform import python_version

print("Версия Python:", python_version())
print("Путь к интерпретатору Python:", sys.executable)
print("Текущая рабочая директория:", os.getcwd())
# Out:
# Версия Python: 3.13.5
# Путь к интерпретатору Python: /opt/anaconda3/bin/python
# Текущая рабочая директория: /Users/khristobostandzhyan/ml/notebooks

# %% [markdown]
# ### Library import check

# %%
import numpy as np
import pandas as pd
import matplotlib as mtpl
import sklearn

print("NumPy version:", np.__version__)
print("Pandas version:", pd.__version__)
print("Matplotlib version:", mtpl.__version__)
print("Scikit-learn version:", sklearn.__version__)
# Out:
# NumPy version: 2.1.3
# Pandas version: 2.2.3
# Matplotlib version: 3.10.0
# Scikit-learn version: 1.6.1

# %% [markdown]
# ### Small sanity check

# %%
data = {
    'Имя': ['Алексей', 'Мария', 'Иван', 'Елена'],
    'Роль': ['Python Dev', 'Data Analyst', 'DevOps', 'Product Manager'],
    'Зарплата_руб': [250000, 180000, 220000, 300000],
    'Кофе_чашек_в_день': [4, 2, 5, 1]
}

df = pd.DataFrame(data)

print("График сотрудников и зарплат:")
print(df)
# Out:
# График сотрудников и зарплат:
#        Имя             Роль  Зарплата_руб  Кофе_чашек_в_день
# 0  Алексей       Python Dev        250000                  4
# 1    Мария     Data Analyst        180000                  2
# 2     Иван           DevOps        220000                  5
# 3    Елена  Product Manager        300000                  1

# %%
result = df["Зарплата_руб"].agg(['mean', 'median', 'min', 'max'])
print("\nСтатистика по зарплатам:")
print(result)
# Out:
# Статистика по зарплатам:
# mean      237500.0
# median    235000.0
# min       180000.0
# max       300000.0
# Name: Зарплата_руб, dtype: float64

# %%
plt =  mtpl.pyplot

data = {'Год': [2010, 2011, 2012, 2013, 2014],
        'Продажи': [200, 300, 400, 500, 600]}

df = pd.DataFrame(data)

df.plot(x='Год', y='Продажи', kind='line')

plt.title('Динамика продаж по годам')
plt.xlabel('Год')
plt.ylabel('Продажи')
plt.show()

# %% [markdown]
# ### Все работает! Готовы к обучению!
#
# Итог: Необходимые библиотеки установлены и работают корректно. Среда готова для обучения!
# Сложно было разобраться с интерпретатором Python, но по гуглив понял что надо было просто его запустить через команду `uv init` а после `uv add ipykernel` и все заработало
